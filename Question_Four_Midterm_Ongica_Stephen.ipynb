# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv('telecom_churn.csv')
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# 0             45.07  ...               99             16.78
# 1             27.47  ...              103             16.62
# 2             41.38  ...              110             10.30
# 3             50.90  ...               88              5.26
# 4             28.34  ...              122             12.61
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    customer service calls  churn
# 0                       1  False
# 1                       1  False
# 2                       0  False
# 3                       2  False
# 4                       3  False
#
# [5 rows x 21 columns]

# %%
features = ['total day minutes', 'total night minutes', 'customer service calls']
X = df[features]

target = 'total day charge'
y = df[target]

# Split the data into training and testing sets (70% for training, 30% for testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Train the Linear Regression model
model = LinearRegression()
model.fit(X_train_scaled, y_train)

# Make predictions
y_train_pred = model.predict(X_train_scaled)
y_test_pred = model.predict(X_test_scaled)

#  Evaluating the model
train_mse = mean_squared_error(y_train, y_train_pred)
test_mse = mean_squared_error(y_test, y_test_pred)

train_rmse = train_mse ** 0.5
test_rmse = test_mse ** 0.5

train_r2 = r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_test_pred)

print("Training Metrics:")
print(f"Mean Squared Error (MSE): {train_mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {train_rmse:.4f}")
print(f"R-squared (R2): {train_r2:.4f}")

print("\nTest Metrics:")
print(f"Mean Squared Error (MSE): {test_mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {test_rmse:.4f}")
print(f"R-squared (R2): {test_r2:.4f}")
# Out:
# Training Metrics:
# Mean Squared Error (MSE): 0.0000
# Root Mean Squared Error (RMSE): 0.0028
# R-squared (R2): 1.0000
#
# Test Metrics:
# Mean Squared Error (MSE): 0.0000
# Root Mean Squared Error (RMSE): 0.0029
# R-squared (R2): 1.0000

# %%
coefficients = model.coef_
intercept = model.intercept_

print("Model Parameters:")
print(f"Intercept (Bias): {intercept:.4f}")
for i, feature in enumerate(features):
    print(f"Coefficient for {feature}: {coefficients[i]:.4f}")


equation = f"Predicted {target} = {intercept:.4f}"
for i, feature in enumerate(features):
    equation += f" + ({coefficients[i]:.4f} * {feature})"
print("\nLinear Equation:")
print(equation)
# Out:
# Model Parameters:
# Intercept (Bias): 30.6038
# Coefficient for total day minutes: 9.2635
# Coefficient for total night minutes: -0.0000
# Coefficient for customer service calls: -0.0001
#
# Linear Equation:
# Predicted total day charge = 30.6038 + (9.2635 * total day minutes) + (-0.0000 * total night minutes) + (-0.0001 * customer service calls)

# %%
train_mse = mean_squared_error(y_train, y_train_pred)
test_mse = mean_squared_error(y_test, y_test_pred)

print("Mean Squared Error (MSE):")
print(f"Training MSE: {train_mse:.4f}")
print(f"Test MSE: {test_mse:.4f}")
# Out:
# Mean Squared Error (MSE):
# Training MSE: 0.0000
# Test MSE: 0.0000

# %%
import pandas as pd
import numpy as np

new_record = {
    'total day minutes': 12,
    'total night minutes': 17,
    'customer service calls': 21
}

new_record_df = pd.DataFrame([new_record])

# Scale the numeric features using the same scaler used for training
new_record_scaled = scaler.transform(new_record_df)

prediction = model.predict(new_record_scaled)

print(f"Predicted total day charge: {prediction[0]:.4f}")
# Out:
# Predicted total day charge: 2.0396
