# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
df = pd.read_csv('telecom_churn.csv')
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
features = ['total day minutes', 'total night minutes', 'customer service calls', 'international plan']
X = df[features]

X['international plan'] = X['international plan'].map({'yes': 1, 'no': 0})  # Binary encoding

# Target variable
y = df['churn']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Scaling numeric features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Training a classification model

classf_model = RandomForestClassifier(random_state=42)
classf_model.fit(X_train_scaled, y_train)

# Make predictions
y_pred = clf.predict(X_test_scaled)

# Evaluate the model
print("Classification Report:")
print(classification_report(y_test, y_pred))

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("\nAccuracy Score:")
print(accuracy_score(y_test, y_pred))
# Out:
# C:\Users\SO\AppData\Local\Temp\ipykernel_22496\1713872326.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['international plan'] = X['international plan'].map({'yes': 1, 'no': 0})  # Binary encoding
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.91      0.95      0.93       857
#         True       0.58      0.43      0.49       143
#
#     accuracy                           0.87      1000
#    macro avg       0.74      0.69      0.71      1000
# weighted avg       0.86      0.87      0.86      1000
#
#
# Confusion Matrix:
# [[812  45]
#  [ 82  61]]
#
# Accuracy Score:
# 0.873

# %%
features = ['total day minutes', 'total night minutes', 'customer service calls', 'international plan']
X = df[features].copy()

# Encode categorical variables
X['international plan'] = X['international plan'].map({'yes': 1, 'no': 0})  # Binary encoding

# Target variable
y = df['churn']

# Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Training the classification model
classf_model = RandomForestClassifier(random_state=42)
classf_model.fit(X_train_scaled, y_train)

# Making predictions
y_pred = classf_model.predict(X_test_scaled)

# Evaluating the model
print("Classification Report:")
print(classification_report(y_test, y_pred))

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("\nAccuracy Score:")
print(accuracy_score(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.91      0.95      0.93       857
#         True       0.58      0.43      0.49       143
#
#     accuracy                           0.87      1000
#    macro avg       0.74      0.69      0.71      1000
# weighted avg       0.86      0.87      0.86      1000
#
#
# Confusion Matrix:
# [[812  45]
#  [ 82  61]]
#
# Accuracy Score:
# 0.873

# %%
features = ['total day minutes', 'total night minutes', 'customer service calls', 'international plan']
X = df[features].copy()

X['international plan'] = X['international plan'].map({'yes': 1, 'no': 0})  # Binary encoding

# Target variable
y = df['churn']

# Split the data into training and testing sets (70% for training, 30% for testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Step 4: Train a classification model
classf_model = RandomForestClassifier(random_state=42)
classf_model.fit(X_train_scaled, y_train)

# Evaluating the model on training and testing sets
y_train_pred = classf_model.predict(X_train_scaled)
y_test_pred = classf_model.predict(X_test_scaled)

train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

print(f"Training Accuracy: {train_accuracy:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# Training Accuracy: 1.0000
# Test Accuracy: 0.8730
